# %% [markdown]
# <details>
# <summary>
#
# >#### When to use:
# </summary>
#
# > ### 🧭 **If your script is a stand-alone helper (a CLI-style or notebook companion):**
#
# 📂 **Save it under `tools/`**
#
# **Use `tools/` when:**
#
# * It’s a *utility script you might run directly* (`python tools/notebook_glossary.py`)
# * It’s not imported by your main pipeline
# * It performs a specific job like `build_glossary`, `validate_schema`, or `sync_env`
#
# This keeps your `src/` or `utils/` folders clean and focused on reusable Python modules.
#
# ---
#
# ### 🧩 **If you plan to import functions from it inside notebooks or pipeline code:**
#
# 📂 **Save it under `src/utils/` (or `src/telco_analysis/utils.py`)**
#
# **Use `utils/` when:**
#
# * You expect to reuse its functions inside code, e.g.
#
#   ```python
#   from src.utils.glossary import build_notebook_glossary
#   ```
# * It’s part of your internal library, not a stand-alone tool.
#
# ---
#
# ### ✅ Recommendation (for *you*, right now)
#
# Since this glossary builder is more of a **one-off analysis helper**, not part of your transformation pipeline,
# → **put it in:**
#
# ```
# Telco/tools/notebook_glossary.py
# ```
#
# Later, when you start refactoring reusable functions (Level 4+), you can migrate pieces of it (like `_extract_text_from_notebook`) into
#
# ```
# Telco/src/utils/text_extraction.py
# ```
#
# ---
#
# Would you like me to show you how to make it runnable both ways — as a CLI tool *and* as an importable module (with a `main()` guard and docstring header)?
