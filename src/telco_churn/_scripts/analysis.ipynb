# %%
import sys, os
from pathlib import Path

# Make project root importable (so `import src...` works)
PROJECT_ROOT = Path.cwd().parent          # notebooks/ -> project root
sys.path.append(str(PROJECT_ROOT))

from src.data.loader import DataLoader
from src.utils.config import load_config

CONFIG = load_config(PROJECT_ROOT / "config" / "config.yaml")
loader = DataLoader(CONFIG)
df = loader.load_telco_data(PROJECT_ROOT / "data" / "WA_Fn-UseC_-Telco-Customer-Churn.csv")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 8
#       5 PROJECT_ROOT = Path.cwd().parent          # notebooks/ -> project root
#       6 sys.path.append(str(PROJECT_ROOT))
# ----> 8 from src.data.loader import DataLoader
#       9 from src.utils.config import load_config
#      11 CONFIG = load_config(PROJECT_ROOT / "config" / "config.yaml")
#
# ModuleNotFoundError: No module named 'src.data'

# %%
import sys, os
sys.path.append(os.path.abspath(".."))  # from notebooks/ to project root

from src.config import load_config
from src.data.loader import DataLoader

config = load_config('config/config.yaml')
loader = DataLoader(config)
df = loader.load_telco_data('../resources/data/raw/Telco-Customer-Churn.csv')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[18], line 4
#       1 import sys, os
#       2 sys.path.append(os.path.abspath(".."))  # from notebooks/ to project root
# ----> 4 from src.config import load_config
#       5 from src.data.loader import DataLoader
#       7 config = load_config('config/config.yaml')
#
# ModuleNotFoundError: No module named 'src.config'

# %%
config = load_config('../config/config.yaml')
loader = DataLoader(config)
df = loader.load_telco_data('../resources/data/raw/Telco-Customer-Churn.csv')

# %%
# notebooks/analysis.ipynb
from src.data.loader import DataLoader
from src.config import load_config

config = load_config('config/config.yaml')
loader = DataLoader(config)
df = loader.load_telco_data('../resources/data/raw/Telco-Customer-Churn.csv')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 3
#       1 # notebooks/analysis.ipynb
#       2 from src.data.loader import DataLoader
# ----> 3 from src.config import load_config
#       5 config = load_config('config/config.yaml')
#       6 loader = DataLoader(config)
#
# ModuleNotFoundError: No module named 'src.config'
